# %% [markdown]
# # This is notebook for testing and seeing how can we do RAG in MongoDB itself

# %%
# --- 🔌 Connect to MongoDB ---
from pymongo import MongoClient
from pprint import pprint
from dotenv import load_dotenv
import os
load_dotenv()
MONGODB_URI = os.getenv("MONGO_URI")
DATABASE_NAME = "AIDoc"
COLLECTION_NAME = "diseases"
client = MongoClient(MONGODB_URI)

# %%
# Read from MongoDB
db = client[DATABASE_NAME]
collection = db[COLLECTION_NAME]

# --- 📄 Fetch and print 2 sample documents ---
print("📄 Sample documents from 'diseases':\n")
for doc in collection.find().limit(1):
    pprint(doc)
    print("\n" + "-"*60 + "\n")
# Out:
# 📄 Sample documents from 'diseases':
#
# {'_id': ObjectId('687b0122aeb398e52bb28ca8'),
#  'chapter': {'authors': 'K Ravi, Vallish Shenoy',
#              'end_page': 857,
#              'number': 6,
#              'start_page': 834,
#              'title': 'Arboviral Infections'},
#  'component': {'editor': 'Dilip Mathai',
#                'id': '1C',
#                'title': 'Viral Infections'},
#  'created_at': datetime.datetime(2025, 7, 19, 2, 21, 22, 60000),
#  'extraction_status': 'Success',
#  'medical_content': {'investigations': ['CBC with differential',
#                                         'Platelet count',
#                                         'Hematocrit serial determinations',
#                                         'AST/ALT levels',
#                                         'NS1 antigen test',
#                                         'RT-PCR and serotyping',
#                                         'IgM and IgG antibodies by MAC-ELISA '
#                                         'or indirect IgG-ELISA',
#                                         'Viral isolation in cell culture',
#                                         'Lumbar puncture and CSF analysis',
#                                         'Urine routine and microscopy',
#                                         'Complete blood count for '
#                                         'leukocytosis/neutrophilia',
#                                         'Serology for viral antigen',
#                                         'Diagnosis by rising IgG in paired '
#                                         'sera'],
#                      'patient_advice': ['Look for warning signs',
#                                         'Increase oral fluid intake',
#                                         'Protection from mosquito/tick bites '
#                                         '(nets, repellents)',
#                                         'Rest during acute illness',
#                                         'Domiciliary care if pulse, pulse '
#                                         'pressure, and platelet count normal'],
#                      'prognosis_followup': ['Recovery phase: WBC recover '
#                                             'before platelets',
#                                             'Hematocrit may decrease due to '
#                                             'reabsorbed fluid',
#                                             'Internal bleeding from GI tract '
#                                             'needs monitoring',
#                                             'Full recovery in KFD may require '
#                                             '4 weeks or more',
#                                             'Frequent need for booster doses '
#                                             'for some JE vaccines',
#                                             'Monitor for warning signs and '
#                                             'complications',
#                                             'Hospitalize if symptoms worsen or '
#                                             'red flags present'],
#                      'red_flags': ['Persistent vomiting',
#                                    'Severe abdominal pain',
#                                    'Tender hepatomegaly',
#                                    'Ascites and pleural effusion',
#                                    'Mucosal bleeding',
#                                    'Rising hematocrit with severe '
#                                    'thrombocytopenia',
#                                    'Signs of shock',
#                                    'Bleeding from GI tract, buccal mucosa, '
#                                    'injection site',
#                                    'Convulsions',
#                                    'Decrease in consciousness',
#                                    'Significant mental status change'],
#                      'symptoms': ['Fever',
#                                   'Headache',
#                                   'Vomiting',
#                                   'Pain on moving eyes',
#                                   'Muscle pains',
#                                   'Joint pains',
#                                   'Macular or maculopapular rash',
#                                   'Leukopenia',
#                                   'Neck stiffness',
#                                   'Drowsiness',
#                                   'Disorientation',
#                                   'Stupor or coma',
#                                   'Convulsions',
#                                   'Absent or irregular deep tendon reflexes',
#                                   'Extensor plantar reflex',
#                                   'Erythrocytic diapedesis in skin lesions',
#                                   'Edema',
#                                   'Hemorrhage',
#                                   'Thrombocytopenia',
#                                   'Oligo- or polyarticular arthritis with '
#                                   'joint swelling and redness',
#                                   'Retro-orbital pain',
#                                   'Transient macular rash',
#                                   'Tachycardia',
#                                   'Narrow pulse pressure',
#                                   'Persistent vomiting',
#                                   'Severe abdominal pain',
#                                   'Tender hepatomegaly',
#                                   'Ascites',
#                                   'Pleural effusion',
#                                   'Mucosal bleeding',
#                                   'Seizures',
#                                   'Encephalopathy',
#                                   'Aseptic meningitis/meningoencephalitis',
#                                   'Intracranial hemorrhage',
#                                   'Hepatic failure',
#                                   'Calculus cholecystitis',
#                                   'Acute pancreatitis',
#                                   'Acute kidney injury',
#                                   'Hemolytic uremic syndrome',
#                                   'Sinus bradycardia',
#                                   'Cardiac arrhythmias',
#                                   'Pericarditis',
#                                   'Myocarditis',
#                                   'Acute respiratory distress syndrome (ARDS)',
#                                   'Pulmonary hemorrhages',
#                                   'Myositis',
#                                   'Raised creatine phosphokinase (CPK) levels',
#                                   'Headache',
#                                   'Retro-orbital pain',
#                                   'Myalgia',
#                                   'Arthralgia',
#                                   'Rash',
#                                   'Hemorrhagic manifestation',
#                                   'Black tarry stools',
#                                   'Epistaxis',
#                                   'Gum bleeding',
#                                   'Respiratory distress',
#                                   'Abdominal pain',
#                                   'Altered behavior',
#                                   'Decreased sensorium',
#                                   'Seizures',
#                                   'Dystonia',
#                                   'Abnormal movements (head nodding, lip '
#                                   'smacking, facial grimacing, pill-rolling, '
#                                   'choreoathetosis)',
#                                   'Fever of acute onset',
#                                   'Decrease in level of consciousness',
#                                   'Significant change in mental status',
#                                   'Convulsions',
#                                   'Fever with headache',
#                                   'Severe myalgia',
#                                   'Conjunctivitis',
#                                   'Prostration',
#                                   'Bradycardia',
#                                   'Hypotension',
#                                   'Exanthem on palate',
#                                   'Hemorrhages',
#                                   'Dehydration',
#                                   'Moderate-to-high polymorph leukocytosis '
#                                   'with neutrophilia',
#                                   'Mononuclear cell pleocytosis in CSF',
#                                   'Polyarticular and migratory arthralgia',
#                                   'Cutaneous erythematous dermatitis',
#                                   'Fever with chills',
#                                   'Jaundice',
#                                   'Renal failure',
#                                   'Bleeding from mucosa',
#                                   'Mild febrile illness with headache, '
#                                   'arthralgia, myalgia, conjunctivitis, fever, '
#                                   'vomiting, maculopapular rash, edema of '
#                                   'extremities',
#                                   'Thrombocytopenia and decreased hematocrit',
#                                   'Leukopenia followed by leukocytosis',
#                                   'Albuminuria and granular casts in urine'],
#                      'treatment_steps': ['Paracetamol for fever',
#                                          'Tepid sponging',
#                                          'Increased oral fluid intake',
#                                          'IV fluids 0.9% saline or Ringer’s '
#                                          'lactate 5–7 mL/kg/h, then 3–5 '
#                                          'mL/kg/h',
#                                          'Repeat IV bolus 0.9% saline 10–20 '
#                                          'mL/kg/h for 1 hour if needed',
#                                          'Treat hemorrhagic complications with '
#                                          'fluid replacement',
#                                          'Rest and supportive care for '
#                                          'chikungunya',
#                                          'NSAIDs for chikungunya symptoms',
#                                          'Analgesics for myalgia/headache in '
#                                          'KFD',
#                                          'IV fluids or blood for '
#                                          'dehydration/hemorrhage in KFD',
#                                          'Ribavirin for CCHF',
#                                          'JE: Maintain fluid and electrolyte '
#                                          'balance',
#                                          'Dengue vaccine (Dengvaxia) 3 doses '
#                                          'at 0/6/12 months, ages 9-45 in '
#                                          'endemic areas',
#                                          'Formalin-inactivated KFD vaccine (2 '
#                                          'doses, 1 month apart, boosters at '
#                                          '6–9 months)',
#                                          'JE vaccines as per table (e.g., live '
#                                          'attenuated 0.25-0.5 mL, two doses 1 '
#                                          'year apart)']},
#  'part': {'number': None, 'title': ''},
#  'section': {'editor': '', 'number': 1, 'title': 'INFECTIOUS DISEASES'},
#  'source_row_index': 48,
#  'sub_part': {'id': '', 'title': ''},
#  'updated_at': datetime.datetime(2025, 7, 19, 2, 21, 22, 60000),
#  'volume': 1}
#
# ------------------------------------------------------------

# %%
# --- Topics we'll extract from 'medical_content' ---
# This will help us format the chunks from the medical content
TOPICS = [
    "symptoms",
    "investigations",
    "treatment_steps",
    "red_flags",
    "patient_advice",
    "prognosis_followup"
]

# --- Format document into natural-language RAG chunks ---
def format_chunks_from_doc(doc):
    chunks = []
    disease = doc.get("chapter", {}).get("title", "Unknown Disease")
    chapter = doc.get("chapter", {}).get("number", "")
    component = doc.get("component", {}).get("title", "")
    source = f"AIDoc > {component} > Chapter {chapter}"
    
    medical = doc.get("medical_content", {})

    for topic in TOPICS:
        if topic in medical:
            items = medical[topic]
            if isinstance(items, list) and items:
                joined = ", ".join(items)
                readable_topic = topic.replace('_', ' ')
                sentence = f"{readable_topic.capitalize()} for {disease} include: {joined}."

                chunk = {
                    "disease": disease,
                    "topic": topic,
                    "text": sentence,
                    "source": source,
                    "tags": [component.lower(), topic.lower()]
                }
                chunks.append(chunk)
    return chunks

# --- Preview chunks from first 2 documents ---
total = 0
for doc in collection.find().limit(2):
    chunks = format_chunks_from_doc(doc)
    for chunk in chunks:
        pprint(chunk)
        print("\n---\n")
    total += len(chunks)

print(f"✅ Formatted {total} chunks from 2 documents.")
# Out:
# {'disease': 'Arboviral Infections',
#  'source': 'AIDoc > Viral Infections > Chapter 6',
#  'tags': ['viral infections', 'symptoms'],
#  'text': 'Symptoms for Arboviral Infections include: Fever, Headache, '
#          'Vomiting, Pain on moving eyes, Muscle pains, Joint pains, Macular or '
#          'maculopapular rash, Leukopenia, Neck stiffness, Drowsiness, '
#          'Disorientation, Stupor or coma, Convulsions, Absent or irregular '
#          'deep tendon reflexes, Extensor plantar reflex, Erythrocytic '
#          'diapedesis in skin lesions, Edema, Hemorrhage, Thrombocytopenia, '
#          'Oligo- or polyarticular arthritis with joint swelling and redness, '
#          'Retro-orbital pain, Transient macular rash, Tachycardia, Narrow '
#          'pulse pressure, Persistent vomiting, Severe abdominal pain, Tender '
#          'hepatomegaly, Ascites, Pleural effusion, Mucosal bleeding, Seizures, '
#          'Encephalopathy, Aseptic meningitis/meningoencephalitis, Intracranial '
#          'hemorrhage, Hepatic failure, Calculus cholecystitis, Acute '
#          'pancreatitis, Acute kidney injury, Hemolytic uremic syndrome, Sinus '
#          'bradycardia, Cardiac arrhythmias, Pericarditis, Myocarditis, Acute '
#          'respiratory distress syndrome (ARDS), Pulmonary hemorrhages, '
#          'Myositis, Raised creatine phosphokinase (CPK) levels, Headache, '
#          'Retro-orbital pain, Myalgia, Arthralgia, Rash, Hemorrhagic '
#          'manifestation, Black tarry stools, Epistaxis, Gum bleeding, '
#          'Respiratory distress, Abdominal pain, Altered behavior, Decreased '
#          'sensorium, Seizures, Dystonia, Abnormal movements (head nodding, lip '
#          'smacking, facial grimacing, pill-rolling, choreoathetosis), Fever of '
#          'acute onset, Decrease in level of consciousness, Significant change '
#          'in mental status, Convulsions, Fever with headache, Severe myalgia, '
#          'Conjunctivitis, Prostration, Bradycardia, Hypotension, Exanthem on '
#          'palate, Hemorrhages, Dehydration, Moderate-to-high polymorph '
#          'leukocytosis with neutrophilia, Mononuclear cell pleocytosis in CSF, '
#          'Polyarticular and migratory arthralgia, Cutaneous erythematous '
#          'dermatitis, Fever with chills, Jaundice, Renal failure, Bleeding '
#          'from mucosa, Mild febrile illness with headache, arthralgia, '
#          'myalgia, conjunctivitis, fever, vomiting, maculopapular rash, edema '
#          'of extremities, Thrombocytopenia and decreased hematocrit, '
#          'Leukopenia followed by leukocytosis, Albuminuria and granular casts '
#          'in urine.',
#  'topic': 'symptoms'}
#
# ---
#
# {'disease': 'Arboviral Infections',
#  'source': 'AIDoc > Viral Infections > Chapter 6',
#  'tags': ['viral infections', 'investigations'],
#  'text': 'Investigations for Arboviral Infections include: CBC with '
#          'differential, Platelet count, Hematocrit serial determinations, '
#          'AST/ALT levels, NS1 antigen test, RT-PCR and serotyping, IgM and IgG '
#          'antibodies by MAC-ELISA or indirect IgG-ELISA, Viral isolation in '
#          'cell culture, Lumbar puncture and CSF analysis, Urine routine and '
#          'microscopy, Complete blood count for leukocytosis/neutrophilia, '
#          'Serology for viral antigen, Diagnosis by rising IgG in paired sera.',
#  'topic': 'investigations'}
#
# ---
#
# {'disease': 'Arboviral Infections',
#  'source': 'AIDoc > Viral Infections > Chapter 6',
#  'tags': ['viral infections', 'treatment_steps'],
#  'text': 'Treatment steps for Arboviral Infections include: Paracetamol for '
#          'fever, Tepid sponging, Increased oral fluid intake, IV fluids 0.9% '
#          'saline or Ringer’s lactate 5–7 mL/kg/h, then 3–5 mL/kg/h, Repeat IV '
#          'bolus 0.9% saline 10–20 mL/kg/h for 1 hour if needed, Treat '
#          'hemorrhagic complications with fluid replacement, Rest and '
#          'supportive care for chikungunya, NSAIDs for chikungunya symptoms, '
#          'Analgesics for myalgia/headache in KFD, IV fluids or blood for '
#          'dehydration/hemorrhage in KFD, Ribavirin for CCHF, JE: Maintain '
#          'fluid and electrolyte balance, Dengue vaccine (Dengvaxia) 3 doses at '
#          '0/6/12 months, ages 9-45 in endemic areas, Formalin-inactivated KFD '
#          'vaccine (2 doses, 1 month apart, boosters at 6–9 months), JE '
#          'vaccines as per table (e.g., live attenuated 0.25-0.5 mL, two doses '
#          '1 year apart).',
#  'topic': 'treatment_steps'}
#
# ---
#
# {'disease': 'Arboviral Infections',
#  'source': 'AIDoc > Viral Infections > Chapter 6',
#  'tags': ['viral infections', 'red_flags'],
#  'text': 'Red flags for Arboviral Infections include: Persistent vomiting, '
#          'Severe abdominal pain, Tender hepatomegaly, Ascites and pleural '
#          'effusion, Mucosal bleeding, Rising hematocrit with severe '
#          'thrombocytopenia, Signs of shock, Bleeding from GI tract, buccal '
#          'mucosa, injection site, Convulsions, Decrease in consciousness, '
#          'Significant mental status change.',
#  'topic': 'red_flags'}
#
# ---
#
# {'disease': 'Arboviral Infections',
#  'source': 'AIDoc > Viral Infections > Chapter 6',
#  'tags': ['viral infections', 'patient_advice'],
#  'text': 'Patient advice for Arboviral Infections include: Look for warning '
#          'signs, Increase oral fluid intake, Protection from mosquito/tick '
#          'bites (nets, repellents), Rest during acute illness, Domiciliary '
#          'care if pulse, pulse pressure, and platelet count normal.',
#  'topic': 'patient_advice'}
#
# ---
#
# {'disease': 'Arboviral Infections',
#  'source': 'AIDoc > Viral Infections > Chapter 6',
#  'tags': ['viral infections', 'prognosis_followup'],
#  'text': 'Prognosis followup for Arboviral Infections include: Recovery phase: '
#          'WBC recover before platelets, Hematocrit may decrease due to '
#          'reabsorbed fluid, Internal bleeding from GI tract needs monitoring, '
#          'Full recovery in KFD may require 4 weeks or more, Frequent need for '
#          'booster doses for some JE vaccines, Monitor for warning signs and '
#          'complications, Hospitalize if symptoms worsen or red flags present.',
#  'topic': 'prognosis_followup'}
#
# ---
#
# {'disease': 'HIV and Systemic Involvement: Cardiovascular System',
#  'source': 'AIDoc >  > Chapter 5',
#  'tags': ['', 'symptoms'],
#  'text': 'Symptoms for HIV and Systemic Involvement: Cardiovascular System '
#          'include: Breathlessness, Orthopnea, Paroxysmal nocturnal dyspnea, '
#          'Cough, Hemoptysis, Edema feet, S3 gallop on examination, Basal '
#          'crepitation in lungs, Enlarged liver, Sinus tachycardia on ECG, '
#          'Continuous chest pain, Fever, High-grade fever in endocarditis, '
#          'Angina pectoris, Unstable angina, STEMI/NSTEMI presentations, '
#          'Arrhythmias, Heart blocks, Cardiogenic shock, Right ventricular '
#          'hypertrophy and failure in severe PAH, Cardiac tamponade (rare).',
#  'topic': 'symptoms'}
#
# ---
#
# {'disease': 'HIV and Systemic Involvement: Cardiovascular System',
#  'source': 'AIDoc >  > Chapter 5',
#  'tags': ['', 'investigations'],
#  'text': 'Investigations for HIV and Systemic Involvement: Cardiovascular '
#          'System include: Myocardial biopsy for myocarditis, '
#          'Electrocardiography (ECG) for sinus tachycardia and QT prolongation, '
#          'Echocardiography to assess ejection fraction or DCMP, Diagnostic '
#          'pericardial tapping for pericardial effusion, Blood cultures for '
#          'infective endocarditis.',
#  'topic': 'investigations'}
#
# ---
#
# {'disease': 'HIV and Systemic Involvement: Cardiovascular System',
#  'source': 'AIDoc >  > Chapter 5',
#  'tags': ['', 'treatment_steps'],
#  'text': 'Treatment steps for HIV and Systemic Involvement: Cardiovascular '
#          'System include: Discontinue zidovudine (AZT) if cardiac dysfunction '
#          'develops, Initiate antiretroviral therapy (ART) to decrease cardiac '
#          'manifestations, Treat pericarditis/pericardial effusion based on '
#          'etiology, often antitubercular therapy, Urgent pericardiocentesis '
#          'for cardiac tamponade, IV vancomycin for infective endocarditis due '
#          'to methicillin-resistant S. aureus, Treat CAD as per HIV-negative '
#          'guidelines: balloon angioplasty with drug-eluting stents or bypass, '
#          'Avoid lovastatin, simvastatin, atorvastatin with protease '
#          'inhibitors; use rosuvastatin or pravastatin, Phosphodiesterase '
#          'inhibitors for HIV-associated pulmonary hypertension.',
#  'topic': 'treatment_steps'}
#
# ---
#
# {'disease': 'HIV and Systemic Involvement: Cardiovascular System',
#  'source': 'AIDoc >  > Chapter 5',
#  'tags': ['', 'red_flags'],
#  'text': 'Red flags for HIV and Systemic Involvement: Cardiovascular System '
#          'include: Cardiac tamponade requiring urgent intervention, QT '
#          'prolongation with risk of torsades de pointes, Continuous chest '
#          'pain, breathlessness, fever in pericardial effusion, Right '
#          'ventricular failure in severe pulmonary hypertension.',
#  'topic': 'red_flags'}
#
# ---
#
# {'disease': 'HIV and Systemic Involvement: Cardiovascular System',
#  'source': 'AIDoc >  > Chapter 5',
#  'tags': ['', 'patient_advice'],
#  'text': 'Patient advice for HIV and Systemic Involvement: Cardiovascular '
#          'System include: Avoid statins with drug–drug interactions if taking '
#          'protease inhibitors, Recognize and report chest pain, '
#          'breathlessness, or fever promptly.',
#  'topic': 'patient_advice'}
#
# ---
#
# {'disease': 'HIV and Systemic Involvement: Cardiovascular System',
#  'source': 'AIDoc >  > Chapter 5',
#  'tags': ['', 'prognosis_followup'],
#  'text': 'Prognosis followup for HIV and Systemic Involvement: Cardiovascular '
#          'System include: HIV-related dilated cardiomyopathy carries poor '
#          'prognosis, ART reduces cardiac manifestations and malignancy '
#          'incidence, Monitor for recurrent CAD, especially in first year '
#          '(4–5-fold increased risk).',
#  'topic': 'prognosis_followup'}
#
# ---
#
# ✅ Formatted 12 chunks from 2 documents.
